# %% [markdown]
# # Анализ

# %%
import notebook_setup
from src.config import INTERIM_DATA_DIR
from src.dataset import DatasetIO

# Датасет с 11 видами по умолчанию
# Если датасет не создан выполните команду python -m src.pipelines.data_pipeline create-dataset
# более подробно ознакомиться с документацией выполните команду с параметром --help
base_dataset = DatasetIO.load_dataset_pickle(INTERIM_DATA_DIR / "dataset_metadata.pkl")

# Мультивью датасет созданный из 3d моделей 129*36 с шагом 10 градусов
# Если датасет не создан выполните команду python -m src.pipelines.data_pipeline create-dataset-multiview --
multiview_dataset = DatasetIO.load_dataset_pickle(INTERIM_DATA_DIR / "multiview_dataset_metadata.pkl")

print(f"Base dataset: {base_dataset}")
print(f"Multiview dataset: {multiview_dataset}")
# Out:
# 2025-08-13 14:47:31.762 | INFO     | src.dataset:load_dataset_pickle:332 - Загрузка датасета из D:\workspace\projects\freelance\3d_recognition_analisis\data\interim\dataset_metadata.pkl
# 2025-08-13 14:47:31.767 | SUCCESS  | src.dataset:load_dataset_pickle:337 - Датасет загружен из D:\workspace\projects\freelance\3d_recognition_analisis\data\interim\dataset_metadata.pkl
# 2025-08-13 14:47:31.768 | INFO     | src.dataset:load_dataset_pickle:332 - Загрузка датасета из D:\workspace\projects\freelance\3d_recognition_analisis\data\interim\multiview_dataset_metadata.pkl
# 2025-08-13 14:47:31.788 | SUCCESS  | src.dataset:load_dataset_pickle:337 - Датасет загружен из D:\workspace\projects\freelance\3d_recognition_analisis\data\interim\multiview_dataset_metadata.pkl
# ...
